# %%
# API da Google para acessar o Data Commons, um repositório de dados públicos sobre diversos tópicos, 
# como demografia, economia, saúde, etc.

import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv
from datacommons_client.client import DataCommonsClient
import datacommons_client as dc 
#chave api do data commons
cliente = DataCommonsClient(api_key=" W62TcEqGvRVEn7GGvs0IZDzaEL519yUm9Yrhx9OT5eC1Fy7r")

# %%
receitas = dc.observation.fetch_observations_by_entity_dcid("country/BRA", "dc/g/GovernmentRevenue")
despesas = dc.observation.fetch_observations_by_entity_dcid("country/BRA", "dc/g/GovernmentExpenditure")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 receitas = dc.observation.fetch_observations_by_entity_dcid("country/BRA", "dc/g/GovernmentRevenue")
#       2 despesas = dc.observation.fetch_observations_by_entity_dcid("country/BRA", "dc/g/GovernmentExpenditure")
#
# AttributeError: module 'datacommons_client' has no attribute 'observation'
