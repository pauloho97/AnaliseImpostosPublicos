# %%
import datacommons_client as dc
from datacommons_client.client import DataCommonsClient

# Inicialização do cliente com a chave de API
cliente = DataCommonsClient(api_key="W62TcEqGvRVEn7GGvs0IZDzaEL519yUm9Yrhx9OT5eC1Fy7r")

# %%
# Coleta de dados de receita e despesa do governo para o Brasil
receitas = cliente.observations_dataframe(
    variable_dcids="dc/g/GovernmentRevenue", 
    entity_dcids="country/BRA", 
    date="all"
)

despesas = cliente.observations_dataframe(
    variable_dcids="dc/g/GovernmentExpenditure", 
    entity_dcids="country/BRA", 
    date="all"
)

# Exibição dos primeiros registros para validação
print(receitas.head())
print(despesas.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
